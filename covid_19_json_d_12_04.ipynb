# %% [markdown]
# # Covid-19_json_api
# * auther: Sangkhom sengsoulichanh
# * ນັກສືກສາ ປທ ວິທະຍາສາດຄອມພີວເຕີ ມຊ  ວິສະວະກຳອອກແບບເທັກໂນໂລຊີ EUT.EDU.VN

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('yEiBeyEASRM', width=720, height=405)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import requests

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(f'pandas version:  {pd.__version__}')
print(f'requests version: {requests.__version__}')

# %%
pd.Timestamp.now()

# %% [markdown]
# ## global

# %%
url='https://corona.lmao.ninja/all'
r=requests.get(url)
j=r.json()
j

# %%
type(j)

# %%
j['cases']

# %%
j['deaths']

# %%
j['recovered']

# %%
j['updated']

# %%
type(j['updated'])

# %% [markdown]
# ### ການປ່ຽນເວລາໂໍຊນ(Convert epoch to human-readable date and vice versa)

# %%
pd.datetime.fromtimestamp(1584858474).strftime('%Y-%m-%d %H:%M:%S') #ວິທີຕັດເອົາ3ຕົວເລກທ້າຍຂອງຈຳນວນລວມອັບເດດອອກ

# %%
j['updated'] // 1000 # ສູດຕັດ3ຕົວເລກ ເພື່ອໃຫ້ ວ.ດ.ປ ອອກມາຖືກຕາມ format

# %%
pd.datetime.fromtimestamp(j['updated']//1000).strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### Single country

# %%
country ='usa'
url= f'https://corona.lmao.ninja/countries/{country}'
r=requests.get(url)
j=r.json()
j

# %%
type(j)

# %%
j['cases']

# %%
j['deaths']

# %%
j['recovered']

# %%
type(j)

# %% [markdown]
# ### All countries

# %%
url='https://corona.lmao.ninja/countries'
r = requests.get(url)
j = r.json()
#j
j[:3]

# %%
type(j)

# %%
df = pd.DataFrame(j)
df

# %%
df[df.country=='Vietnam']
# Out:
#            updated  country  \
# 207  1586685146297  Vietnam
#
#                                            countryInfo  cases  todayCases  \
# 207  {'_id': 704, 'iso2': 'VN', 'iso3': 'VNM', 'lat...    258           0
#
#      deaths  todayDeaths  recovered  active  critical  casesPerOneMillion  \
# 207       0            0        144     114         8                   3
#
#      deathsPerOneMillion   tests  testsPerOneMillion
# 207                    0  121821                1252

# %%
df.to_csv('Vn_covid_19_latest.csv', index=False)

# %%
df.to_excel('covid_19_latest.xlsx',index=False)
